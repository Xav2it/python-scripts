# %%
import datetime
import pandas as pd
import requests
import numpy as np

# %%
def workdays(d, end, excluded=(6, 7)):
    days = []
    while d.date() <= end.date():
        if d.isoweekday() not in excluded:
            days.append(d)
        d += datetime.timedelta(days=1)
    return days

# %%
df = pd.DataFrame()
# Here we create the list of business day between the Begin and and date of the request
df['day']= workdays(datetime.datetime(2020, 2, 1),
               datetime.datetime(2020, 2, 29))

# %%
url = "http://api.newchangefx.com/api/data/series/twap"
   
payload = "\r\n["
 
for day in df['day'] :
  if ((day >= datetime.datetime(2020, 3, 1, 0, 0)) and (day < datetime.datetime(2020, 3, 11, 0, 0))) or ((day >= datetime.datetime(2018, 11, 4, 0, 0)) and (day < datetime.datetime(2019, 3, 10, 0, 0))) :
      payload = payload + "{\"currencyPairs\": \"EURUSD\",\r\n  \"startDate\": \"" + day.strftime("%Y-%m-%d ")+ '12:00:00' +  "\",\r\n  \"endDate\": \"" + day.strftime("%Y-%m-%d ")+ '13:00:00' + "\",\r\n  \"interval\": \"1m\"\r\n},"
  else :
      payload = payload + "{\"currencyPairs\": \"EURUSD\",\r\n  \"startDate\": \"" + day.strftime("%Y-%m-%d ")+ '11:00:00' +  "\",\r\n  \"endDate\": \"" + day.strftime("%Y-%m-%d ")+ '12:00:00' + "\",\r\n  \"interval\": \"1m\"\r\n},"
 
payload = payload[:-1] + "]"

headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Basic R2F1dGllcjpTaGFyazEyMw=='
}
 
 
print(payload)
 
response = requests.request("POST", url, headers=headers, data = payload)
result = pd.DataFrame(response.text.splitlines()).loc[1:, :]
result = result[0].str.split(",", expand=True, )
result.to_csv('EURdailyhourspot_Feb.csv')
# Out:
# [{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-03 11:00:00",
#   "endDate": "2020-02-03 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-04 11:00:00",
#   "endDate": "2020-02-04 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-05 11:00:00",
#   "endDate": "2020-02-05 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-06 11:00:00",
#   "endDate": "2020-02-06 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-07 11:00:00",
#   "endDate": "2020-02-07 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-10 11:00:00",
#   "endDate": "2020-02-10 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-11 11:00:00",
#   "endDate": "2020-02-11 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-12 11:00:00",
#   "endDate": "2020-02-12 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-13 11:00:00",
#   "endDate": "2020-02-13 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-14 11:00:00",
#   "endDate": "2020-02-14 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-17 11:00:00",
#   "endDate": "2020-02-17 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-18 11:00:00",
#   "endDate": "2020-02-18 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-19 11:00:00",
#   "endDate": "2020-02-19 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-20 11:00:00",
#   "endDate": "2020-02-20 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-21 11:00:00",
#   "endDate": "2020-02-21 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-24 11:00:00",
#   "endDate": "2020-02-24 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-25 11:00:00",
#   "endDate": "2020-02-25 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-26 11:00:00",
#   "endDate": "2020-02-26 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-27 11:00:00",
#   "endDate": "2020-02-27 12:00:00",
#   "interval": "1m"
# },{"currencyPairs": "EURUSD",
#   "startDate": "2020-02-28 11:00:00",
#   "endDate": "2020-02-28 12:00:00",
#   "interval": "1m"
# }]
